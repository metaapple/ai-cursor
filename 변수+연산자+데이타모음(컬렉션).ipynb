# %% [markdown]
# <a href="https://colab.research.google.com/github/metaapple/ai-cursor/blob/main/%EB%B3%80%EC%88%98%2B%EC%97%B0%EC%82%B0%EC%9E%90%2B%EB%8D%B0%EC%9D%B4%ED%83%80%EB%AA%A8%EC%9D%8C(%EC%BB%AC%EB%A0%89%EC%85%98).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "홍길동"
age = 25
height = 17.5

# %%
print("test")
# Out:
# test

# %%
print(name)
# Out:
# 홍길동

# %%
print(f"이름: {name} \n나이: {age}")
# Out:
# 이름: 홍길동
# 나이: 25

# %%
print(name, age, height, "입니다.")
# Out:
# 홍길동 25 17.5 입니다.

# %%
a = 20
b = 6

# %%
a
# Out:
# 20

# %%
print(a)
b
# Out:
# 20
# 6

# %%
a + b
# Out:
# 26

# %%
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
# Out:
# 26
# 14
# 120
# 3.3333333333333335
# 3
# 2

# %%
students = ['민수', '영희', '철수', '지수', '준호']
students
# Out:
# ['민수', '영희', '철수', '지수', '준호']

# %%
students[0], students[-1], len(students)
# Out:
# ('민수', '준호', 5)

# %%
students[0:2], students[-1]
# Out:
# (['민수', '영희'], [])

# %%
cart = ['사과', '바나나', '우유'] #list(순서, 인덱스, 변경가능)
cart
# Out:
# ['사과', '바나나', '우유']

# %%
cart.append('빵')
cart
# Out:
# ['사과', '바나나', '우유', '빵']

# %%
cart.remove('바나나')
cart
# Out:
# ['사과', '우유', '빵']

# %%
cart.insert(0, '수박')
cart
# Out:
# ['수박', '사과', '우유', '빵']

# %%
cart.insert(0, '수박')
cart
# Out:
# ['수박', '수박', '사과', '우유', '빵']

# %%
set(cart)
# Out:
# {'빵', '사과', '수박', '우유'}

# %%
chul = {"축구", "게임", "영화","독서"}
young = {"영화", "요리", "독서","여행"}

# %%
chul & young
# Out:
# {'독서', '영화'}

# %%
# list, tuple중복제거 --> set()
result = (1, 2, 3, 3, 4)
result
# Out:
# (1, 2, 3, 3, 4)

# %%
result2 = set(result)
result2
# Out:
# {1, 2, 3, 4}

# %%
# tuple --> 변경 list()
result3 = list(result)
result3[0] = 100
result3
# Out:
# [100, 2, 3, 3, 4]

# %%
# 읽기전용으로 tuple()로 변경

# %%
student = {
    "name" : "김민수",
     "age" : 20,
     "major" : "컴퓨터공학",
     "score" : 85,
}
student
# Out:
# {'name': '김민수', 'age': 20, 'major': '컴퓨터공학', 'score': 85}

# %%
student['age']
# Out:
# 20

# %%
student.get('age')
# Out:
# 20

# %%
student['age']  = 200
student
# Out:
# {'name': '김민수', 'age': 200, 'major': '컴퓨터공학', 'score': 85}

# %%
student['age2']  = 200
student
# Out:
# {'name': '김민수', 'age': 200, 'major': '컴퓨터공학', 'score': 85, 'age2': 200}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'major', 'score', 'age2'])

# %%
del student['age2']
student
# Out:
# {'name': '김민수', 'age': 200, 'major': '컴퓨터공학', 'score': 85}
